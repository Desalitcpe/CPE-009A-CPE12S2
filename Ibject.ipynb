# %% [markdown]
# <a href="https://colab.research.google.com/github/Desalitcpe/CPE-009A-CPE12S2/blob/main/Ibject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class car:
    def __init__(self, name, milage):
        self.name = name
        self.milage = milage
obj1 = car("BMW", 30)
obj2 = car("Audi", 25)

print(obj1.name)
print(obj1.milage)
print(obj2.name)
print(obj2.milage)

# %%
class Car:
 def __init__(self,name,speed):
    self.name = name
    self.speed = speed
obj1 = Car("Bugatti",320)
obj2 = Car("Subaru",210)
print(obj1.name)
print(obj1.speed,"km/hr")
print(obj2.name)
print(obj2.speed,"km/hr")

# %%
class car:
    car_type = "sedan"

    def __init__(self, name, milage):
        self.name = name
        self.milage = milage

    def description(self):
        return f"the {self.name} car gives the mileage of {self.milage} miles per gallon."

    def max_speed(self, speed):
        return f"the {self.name} runs at the max speed of  {speed} km/hr"

obj1 = car("BMW", 30)
obj2 = car("Audi", 25)

print(obj1.description())
print(obj2.description())
# Out:
# the BMW car gives the mileage of 30 miles per gallon.
# the Audi car gives the mileage of 25 miles per gallon.

# %%
class Car:
 def __init__(self,name,speed):
    self.name = name
    self.speed = speed
obj1 = Car("Bugatti",320)
obj2 = Car("Subaru",210)
print(obj1.name,obj1.speed)
print(obj2.name,obj2.speed)
def max_speed(self,speed):
    return f"The {self.name} runs at the maximum speed of {speed}km/hr"
print(max_speed(obj1,320))
print(max_speed(obj2,210))

# %%
class Animals:
  def __init__(self,name,habitat,temperature):
    self.name = name
    self.habitat = habitat
    self.temperature = temperature


  def features(self):
    return f"The {self.name} is a {self.temperature}-blooded animal that lives on {self.habitat}."

mammals = Animals("Dog", "Land", "Warm")
birds = Animals("Pigeon", "Air", "Warm")
reptiles = Animals("Bear", "Terrestrial", "Cold")

print(mammals.name)
print(mammals.habitat)

print(birds.name)
print(birds.habitat)

print(reptiles.name)
print(reptiles.habitat)



print(mammals.features())
print(birds.features())
print(reptiles.features())
# Out:
# Dog
# Land
# Sparrow
# Air
# Snake
# Terrestrial
# The Dog is a Warm-blooded animal that lives on Land.
# The Sparrow is a Warm-blooded animal that lives on Air.
# The Snake is a Cold-blooded animal that lives on Terrestrial.

# %% [markdown]
# # **RECITATION**

# %%
class Shape:

    def __init__(self, name, sides):
        self.name = name
        self.sides = sides

    def description(self):
        return f"The {self.name} has {self.sides} sides."


    def area_circle(self, radius):
        return 3.14 * (radius * radius)

    def area_square(self, side):
        return side * side

    def area_rectangle(self, length, width):
        return length * width

    def area_triangle(self, base, height):
        return 0.5 * base * height


obj1 = Shape("Circle", 0)
obj2 = Shape("Square", 4)
obj3 = Shape("Rectangle", 4)
obj4 = Shape("Triangle", 3)


print(obj1.description())
print(f"Area of {obj1.name}: {obj1.area_circle(5)}")

print(obj2.description())
print(f"Area of {obj2.name}: {obj2.area_square(10)}")

print(obj3.description())
print(f"Area of {obj3.name}: {obj3.area_rectangle(5, 10)}")

print(obj4.description())
print(f"Area of {obj4.name}: {obj4.area_triangle(10, 8)}")
# Out:
# The Circle has 0 sides.
# Area of Circle: 78.5
# The Square has 4 sides.
# Area of Square: 100
# The Rectangle has 4 sides.
# Area of Rectangle: 50
# The Triangle has 3 sides.
# Area of Triangle: 40.0
