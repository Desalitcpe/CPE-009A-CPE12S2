# %% [markdown]
# <a href="https://colab.research.google.com/github/Desalitcpe/CPE-009A-CPE12S2/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "("
A = ")"
b = "{"
B = "}"
c = "["
C = "]"

x = input("Enter a string: ")
def check(y):
  if y == a+A or y == b+B or y == c+C:
    return True
  else:
    return False

print(check(x))
# Out:
# Enter a string: ({})
# False
