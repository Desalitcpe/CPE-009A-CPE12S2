# %% [markdown]
# <a href="https://colab.research.google.com/github/Desalitcpe/CPE-009A-CPE12S2/blob/main/Oject%20Oriented%20Programming%201/19/2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
week = ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday',]
for x in week:
  print(x)
# Out:
# sunday
# monday
# tuesday
# wednesday
# thursday
# friday
# saturday

# %%
week = ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday',]
for x in week:
  print(x)
  if x == 'thursday':
    break
# Out:
# sunday
# monday
# tuesday
# wednesday
# thursday

# %%
week = ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday',]
for x in week:
  if x == 'thursday':
    break
print(x)
# Out:
# thursday

# %%
for x in "week":
  print(x)
# Out:
# w
# e
# e
# k

# %%
#for x in range(6):
  #print(x)
for x in range(2, 6, 2):
  print(x)
# Out:
# 2
# 4

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
     print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %%
i = 1
while i < 6:
  print(i)
  i += 1 #i = i+1 assignment oeprator
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    print(i)
  continue
# Out:
# 3

# %%
i = 0
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
adj = "hello"
i = 0

while i < 11:
  print(adj, i)
  i += 1
# Out:
# hello 0
# hello 1
# hello 2
# hello 3
# hello 4
# hello 5
# hello 6
# hello 7
# hello 8
# hello 9
# hello 10

# %%
# +5 points
i = 9

while i > 2:
  print(i)
  i -= 1
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
