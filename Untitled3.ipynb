# %% [markdown]
# <a href="https://colab.research.google.com/github/Desalitcpe/CPE-009A-CPE12S2/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1, 5):
  print(i*"*")
for i in range(5,0,-1):
  print(i*"*")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
